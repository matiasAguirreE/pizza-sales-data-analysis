# %%
from google.colab import drive
import shutil
import pandas as pd
import matplotlib.pyplot as plt

# Mount google drive on google colab
drive.mount('/content/drive')

# Copy the CSV file from google drive to google colab
shutil.copy('/content/drive/MyDrive/University/5-Semester/Bases-de-Datos/Proyecto/Resultados/05_result.csv', '05_result.csv')

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('05_result.csv')

# Create a bar plot
plt.figure(figsize=(12, 6))
bar_width = 0.4
plt.bar(df['mes'] + bar_width/2, df['total_pizzas_vendidas'], color='blue')

# Adjust the bar width by scaling the width of the rectangle
for rect in plt.gca().patches:
    rect.set_width(0.4)

# Add labels and title
plt.xlabel('Month')
plt.ylabel('Total Pizzas Sold')
plt.title('Month with Historical Sales')

# Set the x-axis to only show the value 7
plt.xticks([7])

# Show the plot
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
